# %%
import pandas as pd 
import seaborn as sns 
#set style for seaborn
sns.set(style = 'darkgrid')

# %%
url = '../input/employee-data/employee_data.csv'
df_employees = pd.read_csv(url)

# %%
df_employees.head(5)
# Out:
#           Employee Name  Employee Number  Age  Pay Rate State         DOB  \
# 0            Brown, Mia       1103024456   30     28.50    MA  11/24/1987
# 1  LaRotonda, William         1106026572   34     23.00    MA   4/26/1984
# 2      Steans, Tyrone         1302053333   31     29.00    MA    9/1/1986
# 3       Howard, Estelle       1211050782   32     21.50    MA   9/16/1985
# 4           Singh, Nan        1307059817   30     16.56    MA   5/19/1988
#
#       Sex CitizenDesc Hispanic/Latino                   RaceDesc Date of Hire  \
# 0  Female  US Citizen              No  Black or African American   10/27/2008
# 1    Male  US Citizen              No  Black or African American     1/6/2014
# 2    Male  US Citizen              No                      White    9/29/2014
# 3  Female  US Citizen              No                      White    2/16/2015
# 4  Female  US Citizen              No                      White     5/1/2015
#
# ...

# %%
df_employees.shape
# Out:
# (310, 19)

# %%
df_employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Employee Name        310 non-null    object
#  1   Employee Number      310 non-null    int64
#  2   Age                  310 non-null    int64
#  3   Pay Rate             310 non-null    float64
#  4   State                310 non-null    object
#  5   DOB                  310 non-null    object
#  6   Sex                  310 non-null    object
#  7   CitizenDesc          310 non-null    object
#  8   Hispanic/Latino      310 non-null    object
#  9   RaceDesc             310 non-null    object
#  10  Date of Hire         310 non-null    object
#  11  Date of Termination  103 non-null    object
#  12  Reason For Term      310 non-null    object
#  13  Employment Status    310 non-null    object
#  14  Department           310 non-null    object
# ...

# %%
sns.displot(df_employees, x = 'Pay Rate', kind = 'kde')

# %%
sns.boxplot(x = 'Sex', y = 'Pay Rate', data = df_employees)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Pay Rate'>
